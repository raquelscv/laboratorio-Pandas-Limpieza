# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Limpieza de Datos
#
# En este laboratorio usaremos el DataFrame de Netflix completo creado en los primeros laboratorios de Pandas.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.
#
# 3. Documenta todas las funciones creadas durante el ejercicio.
#
# 4. Debes incluir después de cada gráfica la interpretación de las mismas en una celda de markdown.

# %%
#Importo la libreria de pandas
import pandas as pd

# %%
#Importo la libreria de numpy
import numpy as np

# %%
#Configuro para que al ejecutar aparezcan todas las columnas de la base de datos
pd.set_option("display.max_columns", None)

# %%
#Importo el csv de netflix con el que voy a trabajar
df_netflix_final = pd.read_csv("datos/Netflix_union_final.csv", index_col = 0)
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    Date_added  Release_year Rating   Duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA        NaN
# 3  2021-09-24          2021  TV-MA        NaN
# 4  2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title
# 0            Yes
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# ## Parte 1: Limpieza y Preparación de Datos

# %% [markdown]
# #### Ejercicio 1: Estandarización y limpieza de columnas
#
# En este ejercicio, debes limpiar y estandarizar algunas columnas clave para hacerlas más manejables y consistentes en tus análisis. Específicamente, trabajarás con las columnas `date_added` y `duration` para convertirlas a un formato uniforme y estructurado.
#
# Instrucciones:
#
# 1. **Convertir la columna `date_added`**: La columna `date_added` contiene fechas en formato de texto. Debes convertirla a un formato `datetime` que pandas pueda entender y manejar fácilmente.
#
# 2. **Limpiar la columna `duration`**: La columna `duration` tiene valores en diferentes formatos como "1 Season", "2 Seasons", "90 min", etc. Tu tarea es extraer el número (ya sea el número de temporadas o la cantidad de minutos) y crear una nueva columna llamada `duration_cleaned` con esos valores estandarizados.
#
#
# **Resultado Esperado:**
# Deberás obtener algo como esto:
#
# | duration   | duration_cleaned |
# |------------|-----------------|
# | 1 Season   | 1               |
# | 90 min     | 90              |
# | 2 Seasons  | 2               |
# | 45 min     | 45              |
# | 3 Seasons  | 3               |

# %%
#Me saco un ejemplo para comenzar observando las dos columnas con las que voy a trabajar (Date_added y Duration)
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    Date_added  Release_year Rating   Duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA        NaN
# 3  2021-09-24          2021  TV-MA        NaN
# 4  2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title
# 0            Yes
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
#Confirmo que la columna Date_added es de tipo object
df_netflix_final["Date_added"].dtypes
# Out:
# dtype('O')

# %%
#Cambio el tipo de dato de la columna Date_added de object a datetime
df_netflix_final["Date_added"] = pd.to_datetime(df_netflix_final["Date_added"])

# %%
#Confirmo que el cambio se ha realizado correctamente
df_netflix_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, 0 to 8806
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Show_id         8807 non-null   object
#  1   Type            8807 non-null   object
#  2   Title           8807 non-null   object
#  3   Director        6173 non-null   object
#  4   Cast            7982 non-null   object
#  5   Country         7976 non-null   object
#  6   Date_added      8797 non-null   datetime64[ns]
#  7   Release_year    8807 non-null   int64
#  8   Rating          8803 non-null   object
#  9   Duration        3994 non-null   object
#  10  Listed_in       8807 non-null   object
#  11  Description     8807 non-null   object
#  12  Genre           513 non-null    object
#  13  Premiere        513 non-null    object
#  14  Runtime         513 non-null    float64
#  15  IMDB_score      513 non-null    float64
#  16  Language        513 non-null    object
#  17  Month_premiere  513 non-null    object
#  18  Year_premiere   513 non-null    float64
#  19  Day_premiere    513 non-null    object
#  20  Original_title  513 non-null    object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(16)
# memory usage: 1.5+ MB

# %%
#Compruebo que aspecto tiene esta columna después de hacer el cambio del tipo de dato y parece que esta correcto
df_netflix_final.sample()
# Out:
#      Show_id     Type            Title Director  \
# 2523   s2524  TV Show  Madam Secretary      NaN
#
#                                                    Cast        Country  \
# 2523  Téa Leoni, Tim Daly, Bebe Neuwirth, Zeljko Iva...  United States
#
#      Date_added  Release_year Rating Duration  Listed_in  \
# 2523 2020-05-15          2019  TV-PG      NaN  TV Dramas
#
#                                             Description Genre Premiere  \
# 2523  When a highly capable woman becomes secretary ...   NaN      NaN
#
#       Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 2523      NaN         NaN      NaN            NaN            NaN          NaN
#
#      Original_title
# 2523            NaN

# %% [markdown]
# Para crear la nueva columna Duration_cleaned que solo contenga el número de temporadas y minutos voy a utilizar el método str.split() indicando que me divida la cadena de la columna Duration por el espacio (esto me generaría una lista con los dos elementos). En el índice 0 estaría la información que queremos para la nueva columna (el número de temporadas o minutos) y en el índice 1 estaría información que no queremos para la nueva columna ("Seasons" o "min"). Por tanto, lo que voy a hacer es a continuación del método indicar que para la nueva columna quiero el primer índice (el 0), es decir, la primera parte del split. He visitado la siguiente página: https://saturncloud.io/blog/how-to-extract-first-and-last-words-from-strings-as-a-new-column-in-pandas/

# %%
#Creación de la nueva columna Duration_cleaned a partir de Duration con el método split
df_netflix_final["Duration_cleaned"] = df_netflix_final["Duration"].str.split(" ").str[0]

# %%
#Compruebo que se han generado bien
df_netflix_final.sample()
# Out:
#      Show_id   Type Title          Director  \
# 4177   s4178  Movie    IO  Jonathan Helpert
#
#                                                 Cast        Country  \
# 4177  Margaret Qualley, Anthony Mackie, Danny Huston  United States
#
#      Date_added  Release_year Rating Duration                 Listed_in  \
# 4177 2019-01-18          2019  TV-14      NaN  Dramas, Sci-Fi & Fantasy
#
#                                             Description  \
# 4177  As a young scientist searches for a way to sav...
#
#                       Genre    Premiere  Runtime  IMDB_score Language  \
# 4177  Science fiction/Drama  2019-01-18     95.0         4.7  English
#
#      Month_premiere  Year_premiere Day_premiere Original_title  \
# 4177        January         2019.0      Viernes            Yes
#
#      Duration_cleaned
# 4177              NaN

# %% [markdown]
# #### Ejercicio 2: Normalización de la columna `rating`
#
# La columna `rating` tiene diferentes calificaciones como `PG`, `PG-13`, `R`, entre otras. Debes categorizar estas calificaciones en tres grupos:
#
# - **'General Audience'** para calificaciones como `G`, `PG`.
#
# - **'Teens'** para calificaciones como `PG-13`, `TV-14`.
#
# - **'Adults'** para calificaciones como `R`, `TV-MA`.

# %%
#Para poder categorizar todas las calificaciones lo primero que hago es sacar los valores únicos de Rating
df_netflix_final["Rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# Le he pedido a Chatgpt que me agrupe las calificaciones en los 3 grupos de audiencia general, adolescentes y adultos (excepto los valores nulos y los valores erróneos de duración en esta columna que se van a quedar como nulos también). Además las calificaciones de NR y UR las voy a meter en una categoría llamada "Not Classified". Me ha devuelto el siguiente diccionario:
# rating_groups = {
#     'TV-Y': 'Audiencia General',
#     'TV-Y7': 'Audiencia General',
#     'TV-Y7-FV': 'Audiencia General',
#     'TV-G': 'Audiencia General',
#     'G': 'Audiencia General',
#     'PG': 'Audiencia General',
#     'TV-PG': 'Audiencia General',
#     'PG-13': 'Adolescentes',
#     'TV-14': 'Adolescentes',
#     'R': 'Adultos',
#     'NC-17': 'Adultos',
#     'TV-MA': 'Adultos'
# }

# %%
#Antes de nada identifico los 3 registros donde en Rating aparece erróneamente la duración
categorias_incorrectas = ["66 min", "74 min", "84 min"]
df_rating_incorrecto = df_netflix_final[df_netflix_final["Rating"].isin(categorias_incorrectas)]
df_rating_incorrecto
# Out:
#      Show_id   Type                                 Title    Director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             Cast        Country Date_added  Release_year  Rating Duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      Listed_in                                        Description Genre  \
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...   NaN
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...   NaN
# 5813    Movies  The comic puts his trademark hilarious/thought...   NaN
#
#      Premiere  Runtime  IMDB_score Language Month_premiere  Year_premiere  \
# 5541      NaN      NaN         NaN      NaN            NaN            NaN
# 5794      NaN      NaN         NaN      NaN            NaN            NaN
# 5813      NaN      NaN         NaN      NaN            NaN            NaN
#
#      Day_premiere Original_title Duration_cleaned
# 5541          NaN            NaN              NaN
# 5794          NaN            NaN              NaN
# 5813          NaN            NaN              NaN

# %%
#Las duraciones las paso correctamente a la columna de Duration
df_netflix_final.iloc[5541,9] = "74 min"
df_netflix_final.iloc[5794,9] = "84 min"
df_netflix_final.iloc[5813,9] = "66 min"

# %%
#Voy a generar una funcion llamada categorias_rating donde primero le paso 3 listas una cada cada grupo y luego se va a ir comprobando para cada registro dentro de que lista está de las 3 y en función de en cual esté lo que devolverá será "General Audience", "Teens", "Adults" o lo dejará como nulo si no está en ninguna
def categorias_rating(rating):
    audiencia_general = ["TV-Y", "TV-Y7", "TV-Y7-FV", "TV-G", "TV-PG", "G", "PG"]
    adolescentes = ["PG-13", "TV-14"]
    adultos = ["R", "TV-MA", "NC-17"]
    sin_clasificar = ["NR", "UR"]
    if rating in audiencia_general:
        return "General Audience"
    elif rating in adolescentes:
        return "Teens"
    elif rating in adultos:
        return "Adults"
    elif rating in sin_clasificar:
        return "Not Classified"
    else:
        return np.nan

# %%
#Me voy a generar una nueva columna con estas calificaciones concretas categorizadas y voy a emplear el método apply para la categorizacion
df_netflix_final["Rating_categorized"] = df_netflix_final["Rating"].apply(categorias_rating)

# %%
#Voy a observar la nueva columna creada y comprobar que se ha categorizado correctamente
df_netflix_final.tail()
# Out:
#      Show_id     Type        Title         Director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      Date_added  Release_year Rating   Duration  \
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R        NaN
# 8805 2020-01-11          2006     PG        NaN
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                            Listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             Description Genre Premiere  \
# 8802  A political cartoonist, a crime reporter and a...   NaN      NaN
# 8803  While living alone in a spooky town, a young g...   NaN      NaN
# 8804  Looking to survive in a world taken over by zo...   NaN      NaN
# 8805  Dragged from civilian life, a former superhero...   NaN      NaN
# 8806  A scrappy but poor boy worms his way into a ty...   NaN      NaN
#
#       Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 8802      NaN         NaN      NaN            NaN            NaN          NaN
# 8803      NaN         NaN      NaN            NaN            NaN          NaN
# 8804      NaN         NaN      NaN            NaN            NaN          NaN
# 8805      NaN         NaN      NaN            NaN            NaN          NaN
# 8806      NaN         NaN      NaN            NaN            NaN          NaN
#
#      Original_title Duration_cleaned Rating_categorized
# 8802            NaN              158             Adults
# 8803            NaN                2   General Audience
# 8804            NaN              NaN             Adults
# 8805            NaN              NaN   General Audience
# 8806            NaN              111              Teens

# %% [markdown]
# Ahora, ya dispongo de una columna con las calificaciones categorizadas. Dispongo de 4 grupos y los registros que era nulos se mantienen como nulos, al igual que los 3 corregidos que ahora se mantendrán con valores nulos en esta columna de Rating.

# %% [markdown]
# #### Ejercicio 3: Creación de una columna personalizada basada en el elenco
#
# Vamos a identificar si un actor clave como `Leonardo DiCaprio`, `Tom Hanks`, o `Morgan Freeman` aparece en el elenco.
#
# Usa `apply` y una función lambda para crear una nueva columna llamada `has_famous_actor` que contenga `True` si alguno de estos actores está en la lista de `cast` y `False` en caso contrario.

# %%
#Genero la nueva columna Has_famous_actor aplicando una función lambda que lo que hace es en primer lugar dejar como nulos aquellos registros cuya columna Cast es un nulo. Luego, devuelve True en aquellos títulos donde al menos uno de los 3 actores clave aparezca en la lista de actores (Cast) y False en aquellos donde ningun actor clave aparece en Cast
df_netflix_final["Has_famous_actor"] = df_netflix_final.apply(lambda x: np.nan if pd.isnull(x["Cast"]) else True if "Leonardo DiCaprio" in x["Cast"] or "Tom Hanks" in x["Cast"] or "Morgan Freeman" in x["Cast"] else False, axis=1)
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False

# %% [markdown]
# #### Ejercicio 4: Creación de una columna personalizada usando lógica condicional
#
# Vamos a crear una columna llamada `is_recent` que identifique si un título fue lanzado en los últimos 5 años.
#
# Crea una función para marcar con `True` si el título es reciente (lanzado en los últimos 5 años) y `False` si no lo es.

# %%
#Me saco los valores unicos (ordenados) de la columna de año de lanzamiento para observar cuales son los últimos 5 años en la base de datos
df_netflix_final["Release_year"].sort_values().unique()
# Out:
# array([1925, 1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958,
#        1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
#Creo una funcion donde va a entrar el año de lanzamiento y si ese año esta dentro de la lista que contiene los ultimos 5 años (2017, 2018, 2019, 2020 y 2021) entonces va a devolver True, y si no está dentro de la lista devuelve False
def lanzado_ultimos_años(año):
    ultimos_años = [2017, 2018, 2019, 2020, 2021]
    if año in ultimos_años:
        return True
    else:
        return False

# %%
#Creo la nueva columna llamando a la de Release_year a la que le aplico la función creada 
df_netflix_final["Is_recent"] = df_netflix_final["Release_year"].apply(lanzado_ultimos_años)

# %%
#Compruebo que la nueva columna se ha generado correctamente y funciona bien
df_netflix_final.tail()
# Out:
#      Show_id     Type        Title         Director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    Cast        Country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      Date_added  Release_year Rating   Duration  \
# 8802 2019-11-20          2007      R    158 min
# 8803 2019-07-01          2018  TV-Y7  2 Seasons
# 8804 2019-11-01          2009      R        NaN
# 8805 2020-01-11          2006     PG        NaN
# 8806 2019-03-02          2015  TV-14    111 min
#
#                                            Listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             Description Genre Premiere  \
# 8802  A political cartoonist, a crime reporter and a...   NaN      NaN
# 8803  While living alone in a spooky town, a young g...   NaN      NaN
# 8804  Looking to survive in a world taken over by zo...   NaN      NaN
# 8805  Dragged from civilian life, a former superhero...   NaN      NaN
# 8806  A scrappy but poor boy worms his way into a ty...   NaN      NaN
#
#       Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 8802      NaN         NaN      NaN            NaN            NaN          NaN
# 8803      NaN         NaN      NaN            NaN            NaN          NaN
# 8804      NaN         NaN      NaN            NaN            NaN          NaN
# 8805      NaN         NaN      NaN            NaN            NaN          NaN
# 8806      NaN         NaN      NaN            NaN            NaN          NaN
#
#      Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 8802            NaN              158             Adults            False
# 8803            NaN                2   General Audience              NaN
# 8804            NaN              NaN             Adults            False
# 8805            NaN              NaN   General Audience            False
# 8806            NaN              111              Teens            False
#
#       Is_recent
# 8802      False
# 8803       True
# 8804      False
# 8805      False
# 8806      False

# %% [markdown]
# #### Ejercicio 5: Clasificación de películas por década
#
# En este ejercicio, tu objetivo es categorizar los años de lanzamiento de las películas o series en décadas. La columna `release_year` contiene el año de lanzamiento y debes crear una nueva columna llamada `decade` que indique la década correspondiente, como "1990s", "2000s", etc.

# %%
#Sacamos los valores únicos de Release_year para observar el año mínimo y máximo del que disponemos 
df_netflix_final["Release_year"].sort_values().unique()
# Out:
# array([1925, 1942, 1943, 1944, 1945, 1946, 1947, 1954, 1955, 1956, 1958,
#        1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969,
#        1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013,
#        2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %% [markdown]
# Con los años ordenados, contamos con películas lanzadas desde 1925 hasta 2021, es decir, vamos a categorizarla y vamos a contar con las siguientes décadas: desde 1920s hasta 2020s. Voy a utilizar el método pd.cut para categorizar los años de lanzamiento por décadas.

# %%
#Lo primero que hago es definir los límites de los intervalos. Como por defecto right=True los intervalos serán: (1919,1929], (1929, 1939], (1939, 1949] ...
bins = [1919, 1929, 1939, 1949, 1959, 1969, 1979, 1989, 1999, 2009, 2019, 2029]

#Lo segundo, defino las etiquetas (décadas) para cada intervalo. Es decir, para el primer intervalo: (1919, 1929] la etiqueta será: "1920s" y así sucesivamente. 
labels = ['1920s', '1930s', '1940s', '1950s', '1960s', '1970s', '1980s', '1990s', '2000s', '2010s', '2020s']

#Por último, creo la columna Decade que va a ser la categorizada. Empleo el método pd.cut llamando a la columna de año de lanzamiento y meto los intervalos y las etiquetas previamente definidas.
df_netflix_final["Decade"] = pd.cut(df_netflix_final["Release_year"], bins=bins, labels=labels)

#Compruebo que se ha generado correctamente la columna
df_netflix_final.sample()
# Out:
#      Show_id   Type          Title                     Director  \
# 2132   s2133  Movie  Project Power  Henry Joost, Ariel Schulman
#
#                                                    Cast        Country  \
# 2132  Jamie Foxx, Joseph Gordon-Levitt, Dominique Fi...  United States
#
#      Date_added  Release_year Rating Duration           Listed_in  \
# 2132 2020-08-14          2020      R  113 min  Action & Adventure
#
#                                             Description      Genre  \
# 2132  An ex-soldier, a teen and a cop collide in New...  Superhero
#
#         Premiere  Runtime  IMDB_score Language Month_premiere  Year_premiere  \
# 2132  2020-08-14    113.0         6.0  English         August         2020.0
#
#      Day_premiere Original_title Duration_cleaned Rating_categorized  \
# 2132      Viernes            Yes              113             Adults
#
#      Has_famous_actor  Is_recent Decade
# 2132            False       True  2020s

# %% [markdown]
# #### Ejercicio 6: Extracción de información
#
# Para practicar la extracción de información:
#
# 1. **Extrae el primer actor** de la lista en la columna `cast` y crea una nueva columna llamada `first_actor`.
#
# 2. **Extrae el primer nombre del director** y guárdalo en una columna llamada `first_name_director`.

# %% [markdown]
# Para este ejercicio voy a utilizar el método str.split() de la misma forma que en el ejercicio 1, solo que en este caso en vez de separar por espacio separo por coma

# %%
#Genero la nueva columna First_actor a partir de la columna Cast aplicando el método split y quedándome con el primer elemento (índice 0)
df_netflix_final["First_actor"] = df_netflix_final["Cast"].str.split(",").str[0]
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False
#
#    Is_recent Decade    First_actor
# 0       True  2020s            NaN
# 1       True  2020s     Ama Qamata
# 2       True  2020s  Sami Bouajila
# 3       True  2020s            NaN
# 4       True  2020s     Mayur More

# %%
#De la misma forma, genero la columna First_name_director a partir de la columna Director
df_netflix_final["First_name_director"] = df_netflix_final["Director"].str.split(",").str[0]
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False
#
#    Is_recent Decade    First_actor First_name_director
# 0       True  2020s            NaN     Kirsten Johnson
# 1       True  2020s     Ama Qamata                 NaN
# 2       True  2020s  Sami Bouajila     Julien Leclercq
# 3       True  2020s            NaN                 NaN
# 4       True  2020s     Mayur More                 NaN

# %% [markdown]
# #### Ejercicio 7: Limpieza de la columna `cast`
#
# La columna `cast` contiene una lista de actores separados por comas. Tu objetivo es realizar las siguientes tareas:
#
# 1. **Reemplaza los valores nulos** en la columna `cast` por "sin información".
#
# 2. **Contar el número de actores** en cada entrada y crear una nueva columna llamada `num_cast`.
#
# 3. **Normalizar los nombres**: Asegúrate de que los nombres de los actores estén en un formato consistente (por ejemplo, quitar espacios adicionales).

# %%
#Reemplazo los valores nulos de la columna Cast por "sin informacion" con el metodo fillna() con un valor específico
df_netflix_final["Cast"] = df_netflix_final["Cast"].fillna("Sin informacion")
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                    Sin informacion  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                    Sin informacion            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False
#
#    Is_recent Decade    First_actor First_name_director
# 0       True  2020s            NaN     Kirsten Johnson
# 1       True  2020s     Ama Qamata                 NaN
# 2       True  2020s  Sami Bouajila     Julien Leclercq
# 3       True  2020s            NaN                 NaN
# 4       True  2020s     Mayur More                 NaN

# %%
#Defino una funcion que cuente el numero de actores y actrices: si entra "sin informacion" devuelve lo mismo. Si entra una lista de actores y actrices lo que hace es aplicar el metodo split (separando por comas) que genera una lista de python donde cada elemento es cada nombre. Por último, para sacar el número lo que devuelve la función es la longitud de esa lista.
def contar_actores(actores):
    if actores == "Sin informacion":
        return actores
    else:
        lista_actores = actores.split(",")
        return len(lista_actores)

# %%
#Genero la columna nueva num_cast aplicando a la columna Cast la función previamente definida 
df_netflix_final["Num_cast"] = df_netflix_final["Cast"].apply(contar_actores)
df_netflix_final.sample()
# Out:
#      Show_id     Type     Title Director  \
# 2643   s2644  TV Show  Love 101      NaN
#
#                                                    Cast Country Date_added  \
# 2643  Pınar Deniz, Kubilay Aka, Mert Yazıcıoğlu, Ali...  Turkey 2020-04-24
#
#       Release_year Rating Duration  \
# 2643          2020  TV-MA      NaN
#
#                                              Listed_in  \
# 2643  International TV Shows, TV Dramas, Teen TV Shows
#
#                                             Description Genre Premiere  \
# 2643  While trying to make their teacher fall for a ...   NaN      NaN
#
#       Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 2643      NaN         NaN      NaN            NaN            NaN          NaN
#
#      Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 2643            NaN              NaN             Adults            False
#
#       Is_recent Decade  First_actor First_name_director Num_cast
# 2643       True  2020s  Pınar Deniz                 NaN       10

# %%
#Para asegurarme de que los nombres están en un formato consistente, voy a str.strip() que va a eliminar los espacios en blanco al principio y al final de cada cadena
df_netflix_final["Cast"] = df_netflix_final["Cast"].str.strip()
df_netflix_final.sample()
# Out:
#      Show_id   Type               Title       Director  \
# 6444   s6445  Movie  Chaotic Love Poems  Garin Nugroho
#
#                                Cast    Country Date_added  Release_year  \
# 6444  Chicco Jerikho, Pevita Pearce  Indonesia 2019-01-05          2016
#
#      Rating Duration                                      Listed_in  \
# 6444  TV-14      NaN  Dramas, International Movies, Romantic Movies
#
#                                             Description Genre Premiere  \
# 6444  Spanning the 1970s, ‘80s and ‘90s, this lyrica...   NaN      NaN
#
#       Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 6444      NaN         NaN      NaN            NaN            NaN          NaN
#
#      Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 6444            NaN              NaN              Teens            False
#
#       Is_recent Decade     First_actor First_name_director Num_cast
# 6444      False  2010s  Chicco Jerikho       Garin Nugroho        2

# %% [markdown]
# #### Ejercicio 9: Identificación de Directores Recurrentes
#
# En este ejercicio, debes identificar los directores que aparecen más de una vez en el conjunto de datos. Realiza los siguientes pasos:
#
# 1. **Reemplaza los valores nulos** en la columna `director` por "sin información".
#
# 3. **Cuenta cuántas veces aparece cada director** en la columna creada en el ejercicio 6.
#
# 4. **Filtra aquellos directores que aparecen más de una vez** y crea una nueva columna llamada `recurrent_director` donde se indique "Yes" si el director aparece varias veces o "No" en caso contrario.

# %%
#Reemplazo los valores nulos de la columna Director por "sin informacion" con el metodo fillna() con un valor específico
df_netflix_final["Director"] = df_netflix_final["Director"].fillna("Sin informacion")
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water  Sin informacion
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Sin informacion
# 4      s5  TV Show           Kota Factory  Sin informacion
#
#                                                 Cast        Country  \
# 0                                    Sin informacion  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                    Sin informacion            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False
#
#    Is_recent Decade    First_actor First_name_director         Num_cast
# 0       True  2020s            NaN     Kirsten Johnson  Sin informacion
# 1       True  2020s     Ama Qamata                 NaN               19
# 2       True  2020s  Sami Bouajila     Julien Leclercq                9
# 3       True  2020s            NaN                 NaN  Sin informacion
# 4       True  2020s     Mayur More                 NaN                8

# %% [markdown]
# Si cuento cuantas veces aparece cada director en la columna creada en el ejercicio 6 (First_name_director) voy a estar contando cuantas veces aparece cada primer director de la lista de directores de cada titulo como primer director también en otros títulos

# %%
#Creo una función que va a contar cuantas veces aparece cada director en la columna First_name_director. Como parámetro entrará la columna e irá iterando por ella. Lo primero es que apendea cada director en una lista de forma que a continuación se pueda contar cada director cuantas veces aparece en esa lista y lo recojo en un diccionario (nombre del director y las veces que aparece en la columna).
def veces_director(directores):
    nombres = []
    dicc_directores = {}
    for director in directores:
        if pd.notnull(director):
            nombres.append(director)
    for nombre in nombres:
        clave = nombre
        valor = nombres.count(nombre)
        dicc_directores.update({clave:valor})
    return dicc_directores

numero_veces_director = veces_director(df_netflix_final["First_name_director"])
numero_veces_director
# Out:
# {'Kirsten Johnson': 1,
#  'Julien Leclercq': 3,
#  'Mike Flanagan': 4,
#  'Robert Cullen': 1,
#  'Haile Gerima': 1,
#  'Andy Devonshire': 1,
#  'Theodore Melfi': 1,
#  'Kongkiat Komesiri': 1,
#  'Christian Schwochow': 1,
#  'Bruno Garotti': 4,
#  'Pedro de Echave García': 1,
#  'Adam Salky': 1,
#  'Olivier Megaton': 2,
#  'K.S. Ravikumar': 1,
#  'Alex Woo': 3,
#  'S. Shankar': 1,
#  'Rajiv Menon': 3,
#  'Dennis Dugan': 4,
#  'Scott Stewart': 2,
#  'Robert Luketic': 6,
#  'Ashwiny Iyer Tiwari': 2,
#  'Daniel Sandu': 1,
#  'Cédric Jimenez': 1,
#  'George Nolfi': 1,
#  'Steven Spielberg': 11,
#  'Jeannot Szwarc': 1,
#  'Joe Alves': 1,
#  'Joseph Sargent': 1,
#  'Tyler Greco': 1,
#  'Daniel Espinosa': 1,
#  'Bunmi Ajakaiye': 2,
#  'Antoine Fuqua': 4,
#  'Toshiya Shinohara': 7,
#  'Masahiko Murata': 4,
#  'Hajime Kamegaki': 2,
#  'Hirotsugu Kawasaki': 1,
#  'Toshiyuki Tsuru': 1,
#  'Tensai Okamura': 2,
#  'David Yarovesky': 1,
#  'Hanns-Bruno Kammertöns': 1,
#  'David A. Vargas': 1,
#  'Kemi Adetiba': 3,
#  'Ben Simms': 2,
#  'Prakash Satam': 7,
#  'Delhiprasad Deenadayalan': 2,
#  'Tomer Eshed': 1,
#  'Cedric Nicolas-Troyan': 1,
#  'JJC Skillz': 1,
#  'Thomas Sieben': 2,
#  'Marcus Clarke': 1,
#  'Alice Waddington': 1,
#  'Mona Achache': 1,
#  'Alexis Almström': 1,
#  'Raja Gosnell': 4,
#  'Stephen Kijak': 1,
#  'Chapman Way': 3,
#  'Jason Hehir': 1,
#  'Yemi Amodu': 1,
#  'Lijo Jose Pellissery': 1,
#  'David de Vos': 1,
#  'Luis Alfaro': 1,
#  'Sara Colangelo': 2,
#  'Stephen Herek': 2,
#  'Rahul Rawail': 1,
#  'Jane Campion': 3,
#  'Nagesh Kukunoor': 5,
#  'Luke Holland': 1,
#  'Shanker Raman': 1,
#  'JP Habac': 2,
#  'Vidhu Vinod Chopra': 1,
#  'Mark Rosman': 1,
#  'Gilles Paquet-Brenner': 3,
#  'Lasse Hallström': 7,
#  'Scott Pleydell-Pearce': 1,
#  'Ridley Scott': 2,
#  'Neill Blomkamp': 2,
#  'Phillip Noyce': 3,
#  'Renny Harlin': 3,
#  'Anthony Minghella': 2,
#  'Simon Wincer': 3,
#  'Spike Lee': 5,
#  'Sebastián Schindel': 3,
#  'Steven C. Miller': 3,
#  'Richard LaGravenese': 2,
#  'Martin Campbell': 5,
#  'Reginald Hudlin': 3,
#  'George Jackson': 1,
#  'Eric Meza': 1,
#  'Gerhard Mostert': 1,
#  'Michael Martin': 1,
#  'Michael Rymer': 1,
#  'Andrew Lau Wai-keung': 1,
#  'Brett Weiner': 1,
#  'Jim Henson': 1,
#  'Gary Winick': 1,
#  'Danishka Esterhazy': 1,
#  'Troy Byer': 1,
#  'Pang Ho-cheung': 3,
#  'Tim Burton': 3,
#  'David Zucker': 4,
#  'Kinka Usher': 1,
#  'Sergio Leone': 2,
#  "Matthew O'Callaghan": 1,
#  'Bobby Farrelly': 2,
#  'Wolfgang Petersen': 3,
#  'Peter Spirer': 3,
#  'Michael Carney': 1,
#  'Richard Linklater': 1,
#  'Amy Rice': 1,
#  'Randal Kleiser': 2,
#  'Michael Ritchie': 1,
#  'J. Lee Thompson': 1,
#  'Evan Goldberg': 1,
#  'Tom Shadyac': 2,
#  'Peter Segal': 4,
#  'Malcolm D. Lee': 2,
#  'Ramzy Bedia': 1,
#  'Sharan Koppisetty': 1,
#  'Taylor Sheridan': 1,
#  'Sachin Yardi': 3,
#  'Saurabh Kabra': 1,
#  'Mark Waters': 3,
#  'Partho Mitra': 1,
#  'Santram Varma': 1,
#  'Anil V. Kumar': 1,
#  'Sangeeth Sivan': 2,
#  'Umesh Ghadge': 1,
#  'David Dhawan': 9,
#  'Dibakar Banerjee': 4,
#  'Apoorva Lakhia': 2,
#  'Milan Luthria': 6,
#  'Pawan Kripalani': 1,
#  'Bhushan Patel': 1,
#  'Magnus Martens': 1,
#  'Raj Nidimoru': 1,
#  'Joshua Rofé': 1,
#  'Brad Anderson': 4,
#  'Mauricio Dias': 1,
#  'Angel Kristi Williams': 1,
#  'Roger Donaldson': 3,
#  'Christopher Alender': 1,
#  'Rush Sturges': 1,
#  'David Oyelowo': 1,
#  'Mark Lo': 1,
#  'Crystal Moselle': 1,
#  'Rathindran R Prasad': 4,
#  'Han Kwang Il': 1,
#  'Karim El Shenawy': 1,
#  'Yin Chen-hao': 1,
#  'Brian Andrew Mendoza': 1,
#  'Dave Needham': 1,
#  'Veronica Velasco': 1,
#  'Drake Doremus': 3,
#  'Miguel Alexandre': 1,
#  'Mani Ratnam': 5,
#  'Michael Harte': 1,
#  'Tosin Igho': 2,
#  'Alice Filippi': 1,
#  'Paakhi Tyrewala': 1,
#  'Laura Brownson': 2,
#  'Steve Brill': 5,
#  'Moses Inwang': 4,
#  'Ferdinando Cito Filomarino': 1,
#  'Juan Carlos Medina': 1,
#  'Inma Torrente': 1,
#  'Julián Gaviria': 1,
#  'Steven Yamamoto': 1,
#  'Charles Uwagbai': 2,
#  'Julián Hernández': 2,
#  'Sam Hobkinson': 2,
#  'Vince Marcello': 5,
#  'Jonathan Teplitzky': 1,
#  'Sakon Tiacharoen': 1,
#  'Floyd Russ': 2,
#  'Dustin Hoffman': 1,
#  'Adze Ugah': 3,
#  'Hideaki Takizawa': 1,
#  'Quoc Bao Tran': 1,
#  'Bejoy Nambiar': 3,
#  'Kayode Kasum': 4,
#  'Just Philippot': 1,
#  'Kirk DeMicco': 1,
#  'Rohit Shetty': 5,
#  'Cavi Borges': 1,
#  'Alejandro Doria': 2,
#  'Laura Fairrie': 1,
#  'Marcelo Piñeyro': 1,
#  'Izu Ojukwu': 1,
#  'Peter Winther': 1,
#  'Susan Lacy': 1,
#  'Billy Corben': 2,
#  'James Mangold': 2,
#  'Chineze Anyaene': 1,
#  'Hsu Fu-chun': 2,
#  'Kristine Stolakis': 1,
#  'Eva Müller': 1,
#  'Brian Levant': 4,
#  'Rod Daniel': 1,
#  'Robert Zemeckis': 3,
#  'Todor Chapkanov': 1,
#  'Phil Lord': 1,
#  'John Hughes': 1,
#  'Justin Baldoni': 1,
#  'Joe Roth': 2,
#  'Mark Helfrich': 1,
#  'Mag Hsu': 1,
#  'Christopher Nolan': 1,
#  'Paul Thomas Anderson': 5,
#  'Nick Castle': 2,
#  'Howard Zieff': 2,
#  'David Feiss': 1,
#  'David Gordon Green': 2,
#  'Jorge Blanco': 1,
#  'Zara Hayes': 1,
#  'Gary Ross': 2,
#  'Clint Eastwood': 7,
#  'Trey Parker': 1,
#  'Kelly Fremon Craig': 1,
#  'Tom Elkins': 1,
#  'Tony Scott': 2,
#  'Brad Furman': 1,
#  'Sylvain White': 1,
#  'Irwin Winkler': 1,
#  'Garry Marshall': 3,
#  'Kenneth Gyang': 3,
#  'Jaume Balagueró': 1,
#  'Najwa Najjar': 2,
#  'Selçuk Metin': 1,
#  'Keishi Otomo': 2,
#  'David Charhon': 1,
#  'Michelle Bello': 1,
#  'Steven Tsuchida': 1,
#  'Daniel Markowicz': 1,
#  'Louie Schwartzberg': 1,
#  'Glen Winter': 1,
#  'Ram Gopal Varma': 7,
#  'David Benullo': 1,
#  'Laxman Utekar': 2,
#  'Royale Watkins': 1,
#  'Yuval Adler': 1,
#  'Quentin Tarantino': 8,
#  'Clay Glen': 4,
#  'Muzi Mthembu': 1,
#  'Marcos Bucay': 2,
#  'Peter Thorwarth': 1,
#  'Kim Seong-hun': 2,
#  'Augustine Frizzell': 1,
#  'Sidheswar Shukla': 2,
#  'Rajiv Chilaka': 22,
#  'Binayak Das': 1,
#  'Arpan Sarkar': 1,
#  'Ainsley Gardiner': 1,
#  'Mahmoud Karim': 3,
#  'Kyohei Ishiguro': 1,
#  'Seyi Babatope': 3,
#  'Johane Matte': 1,
#  'Morgan Ingari': 1,
#  'Abdulaziz Alshlahei': 1,
#  'Edward Drake': 1,
#  'Kathryn Fasegha': 1,
#  'Sita Likitvanichkul': 1,
#  'Leigh Janiak': 3,
#  'Luis Estrada': 2,
#  'Garrett Bradley': 1,
#  'Sofia Coppola': 3,
#  'Colin Trevorrow': 2,
#  'Bill Condon': 2,
#  'David Slade': 1,
#  'Chris Weitz': 3,
#  'Catherine Hardwicke': 1,
#  'Hadrah Daeng Ratu': 1,
#  'Tommy Chong': 1,
#  'Fred Ouro Preto': 1,
#  'Mayye Zayed': 1,
#  'Alessandra de Rossi': 1,
#  'Ash Brannon': 1,
#  'Alaa Eddine Aljem': 1,
#  'Tom Donahue': 2,
#  'Roberto De Feo': 1,
#  'Navot Papushado': 1,
#  'Manuel Alcalá': 1,
#  'Ricardo Trogi': 1,
#  'Semi Chellas': 1,
#  'Akay Mason': 1,
#  'Viridiana Lieberman': 1,
#  'Nima Nourizadeh': 1,
#  'Daniel Růžička': 1,
#  'Juraj Šajmovič': 1,
#  'Femi D. Ogunsanwo': 1,
#  'Douglas Attal': 1,
#  'Kim Joo-hyung': 2,
#  'Avi Federgreen': 1,
#  'Jericca Cleland': 1,
#  'Ahmed Siddiqui': 1,
#  'Hallie Meyers-Shyer': 1,
#  'Scott Speer': 1,
#  'Barry Levinson': 3,
#  'Tolulope Itegboje': 1,
#  'Camille Delamarre': 1,
#  'Pascal Atuma': 1,
#  'Oleg Trofim': 1,
#  'Mahmood Ali-Balogun': 1,
#  'Jan Holoubek': 1,
#  'Anurin Nwunembom': 2,
#  'Christine Luby': 1,
#  'Udoka Oyeka': 1,
#  'Yeo Siew Hua': 1,
#  'Hardik Mehta': 3,
#  'Rajveer Singh Maan': 1,
#  'Youssef Chahine': 12,
#  'Saw Teong Hin': 1,
#  'Rano Karno': 3,
#  'Pramod Pawar': 1,
#  'Naresh Saigal': 1,
#  'Vinil Mathew': 2,
#  'Neri Parenti': 1,
#  'Ramsey Nouah': 2,
#  'Bong Joon Ho': 2,
#  'Kim Tae-hyung': 1,
#  'Michael Spierig': 1,
#  'Ernie Barbarash': 4,
#  'Matt Ogens': 1,
#  'Jay Roach': 5,
#  'McG': 7,
#  'Frank Marshall': 1,
#  'Victor Vu': 1,
#  'Chow Hin Yeung Roy': 1,
#  'Joel Hopkins': 1,
#  'John Stevenson': 1,
#  'Jennifer Yuh Nelson': 1,
#  'Greg Berlanti': 1,
#  'Garth Davis': 1,
#  'Malik Nejer': 2,
#  'Rob Marshall': 2,
#  'Martin Brest': 1,
#  'Shuko Murase': 1,
#  'Paul W.S. Anderson': 3,
#  'Ivan Reitman': 3,
#  'Joel Gallen': 2,
#  'Claire McCarthy': 1,
#  'Mary Lambert': 1,
#  'Sidharta Tata': 1,
#  'Trevor Nunn': 1,
#  'Gabriele Muccino': 3,
#  'Jim Field Smith': 1,
#  'Chris Koch': 1,
#  'J.J. Abrams': 1,
#  'Rob Minkoff': 4,
#  'Lynn Shelton': 5,
#  'Adam McKay': 3,
#  'Anton Corbijn': 1,
#  'Robin Bissell': 1,
#  'David Fincher': 6,
#  'John G. Avildsen': 5,
#  'Alan Parker': 1,
#  'Walter Hill': 3,
#  'Stephen Frears': 2,
#  'Bryan Bertino': 2,
#  'Phil Alden Robinson': 1,
#  'Florian Henckel von Donnersmarck': 2,
#  'Len Wiseman': 1,
#  'Måns Mårlind': 2,
#  'Patrick Tatopoulos': 1,
#  'Robert O. Peters': 3,
#  'Vincent Ward': 1,
#  'Gregory Nava': 1,
#  'Mary Harron': 2,
#  'Matt Thompson': 1,
#  'Jameel Buari': 1,
#  'Shen Leping': 1,
#  'Matt Aselton': 1,
#  'Jose Javier Reyes': 1,
#  'Jakub Piątek': 1,
#  'John Dower': 2,
#  'B. T Thomas': 1,
#  'Andrew Dominik': 1,
#  'Nibal Arakji': 1,
#  'Sofie Šustková': 1,
#  'Anissa Bonnefont': 1,
#  'Bahij Hojeij': 1,
#  'Jonathan Hensleigh': 2,
#  'Srijit Mukherji': 1,
#  'Justin P. Lange': 1,
#  'Kimmy Gatewood': 1,
#  'Tània Balló': 1,
#  'Manolo Caro': 3,
#  'Jayme Monjardim': 1,
#  'Kingsley Ogoro': 2,
#  'Cristina Jacob': 4,
#  'Fernando Moro': 1,
#  'Ivan Andrew Payawal': 1,
#  'Yoshiyuki Tomino': 4,
#  'Rob Seidenglanz': 2,
#  'Simon Frederick': 1,
#  'Michihito Fujii': 1,
#  'Paul Weitz': 2,
#  'Karthik Subbaraj': 3,
#  'Lucky Kuswandi': 2,
#  'Soudade Kaadan': 3,
#  'Antoinette Jadaone': 5,
#  'Marie Clements': 1,
#  'David O. Russell': 2,
#  'Achille Brice': 1,
#  'Max Jabs': 1,
#  'Sarawut Wichiensarn': 1,
#  'Ricardo de Montreuil': 1,
#  'Peter Chelsom': 2,
#  'Michael Lockshin': 1,
#  'Francine Parker': 1,
#  'Daniel Schechter': 1,
#  'Mike Gunther': 4,
#  'David Zeiger': 1,
#  'Michael Simon': 6,
#  'Jerry Rothwell': 3,
#  'Joe Berlinger': 5,
#  'Ian Cheney': 2,
#  'Bradley Parker': 2,
#  'Prabhakaran': 1,
#  'Manjari Makijany': 1,
#  'Jay Oliva': 1,
#  'Chris Appelhans': 1,
#  'Michael Tiddes': 4,
#  'Lara Saba': 1,
#  'Bao Nhan': 1,
#  'Mark Raso': 3,
#  'Tariq Alkazim': 1,
#  'Yulene Olaizola': 1,
#  'Matthew Heineman': 1,
#  'Robert Peters': 1,
#  'Jonathan Clay': 1,
#  'Ally Pankiw': 1,
#  'George Ford': 2,
#  'Lee Kae-byeok': 1,
#  'Jayan Moodley': 2,
#  'Daniel Benmayor': 2,
#  'Alex Díaz': 3,
#  'Helena Bergström': 1,
#  'Alejandro De Grazia': 1,
#  'Myriam Fares': 1,
#  'Chiaki Kon': 1,
#  'Rae Red': 1,
#  'Lance Hool': 1,
#  'Nicole Conn': 1,
#  'Les Mayfield': 3,
#  'Ellen Seidler': 1,
#  'Roger Christian': 1,
#  'Peter Galison': 1,
#  'Lance Young': 1,
#  'Leandro Neri': 1,
#  'Thom Fitzgerald': 1,
#  'Don Michael Paul': 10,
#  'Andrzej Bartkowiak': 3,
#  'Harold Becker': 1,
#  'Andrew Jenks': 1,
#  'Ric Roman Waugh': 3,
#  'Rob Reiner': 4,
#  'Andy Tennant': 5,
#  'Tade Ogidan': 1,
#  'Scott Spiegel': 1,
#  'Jessie Nelson': 1,
#  'Theodore Witcher': 1,
#  'Aurora Guerrero': 1,
#  'Michael Jai White': 1,
#  'James McTeigue': 2,
#  'Takuya Igarashi': 1,
#  'Michelle MacLaren': 1,
#  'Hidenori Inoue': 7,
#  'Todd Phillips': 3,
#  'Steve Ball': 5,
#  'Dominic Sena': 2,
#  'Alan Alda': 1,
#  'Mika Kaurismäki': 1,
#  'Sydney Pollack': 1,
#  'Lorene Scafaria': 1,
#  'Barbra Streisand': 2,
#  'Michael Winterbottom': 2,
#  'Emma Tammi': 1,
#  'Peter Hutchings': 2,
#  'George Ratliff': 1,
#  'Bo Burnham': 4,
#  'Ekene Som Mekwunye': 2,
#  'David Frankel': 1,
#  'Kevin Johnson': 1,
#  'José Larraza': 1,
#  'Gary Sing': 1,
#  'Julio Quintana': 1,
#  'Paween Purijitpanya': 1,
#  'Pablo Faro': 1,
#  'Letizia Lamartire': 1,
#  'Ray Jiang': 1,
#  'Daniel Vernon': 1,
#  'Steve Gukas': 2,
#  'Tim Johnson': 2,
#  'Vishwesh Krishnamoorthy': 1,
#  'Zack Snyder': 2,
#  'Uduak-Obong Patrick': 1,
#  'Mohamed Diab': 2,
#  'Amr Salama': 1,
#  'Christopher Amos': 1,
#  'Robert Rodriguez': 8,
#  'David Ayer': 4,
#  'Eshom Nelms': 1,
#  'James Moll': 1,
#  'James Redford': 1,
#  'Kaashvie Nair': 1,
#  'J.D. Dillard': 2,
#  'Nikhil Pherwani': 1,
#  'Mae Czarina Cruz': 7,
#  'Praveen Kandregula': 1,
#  'Cecilia Verheyden': 1,
#  'Daniel Minahan': 1,
#  'Donovan Marsh': 1,
#  'Brent Dawes': 1,
#  'Leli Maki': 1,
#  'Uzodinma Okpechi': 1,
#  'Daniel Prochaska': 1,
#  'Joe Wright': 1,
#  'Matthew Vaughn': 2,
#  'Aditya Kripalani': 2,
#  'Adriano Rudiman': 3,
#  'David Pablos': 2,
#  'Alexandre Aja': 2,
#  'Cai Cong': 1,
#  'Samuel Olatunji': 1,
#  'Ramon Térmens': 1,
#  'Svetlana Cvetko': 1,
#  'Martin Prakkat': 1,
#  'Baran bo Odar': 2,
#  'Zhang Chong': 1,
#  'Yılmaz Erdoğan': 9,
#  'Shantrelle P. Lewis': 1,
#  'Ivan Ayr': 2,
#  'Anthony Mandler': 1,
#  'Vijay Roche': 1,
#  "Stanley Menino D'Costa": 1,
#  'Jennifer Brea': 1,
#  'Julia von Heinz': 1,
#  'Niels Arden Oplev': 1,
#  'Don Argott': 1,
#  'Joshua Zeman': 1,
#  'Duncan Skiles': 1,
#  'Sean McNamara': 4,
#  'Vondie Curtis-Hall': 1,
#  'Robert Radler': 1,
#  'Roel Reiné': 1,
#  'Dean Parisot': 1,
#  'Paul Greengrass': 3,
#  'Justin Kelly': 2,
#  'Eric Darnell': 3,
#  'Suhas Kadav': 16,
#  'Jeff Wadlow': 2,
#  'Charles Martin': 1,
#  'Stella Corradi': 1,
#  'Roland Emmerich': 3,
#  'Kevin Macdonald': 1,
#  'Ann Deborah Fishman': 1,
#  'Chris Gorak': 1,
#  'Peter Jackson': 3,
#  'Roger Kumble': 4,
#  'Jonathan Lynn': 1,
#  'Courtney Hunt': 2,
#  'Pierre Greco': 1,
#  'Andrew Davis': 1,
#  'Kevin Smith': 5,
#  'Chaitanya Tamhane': 1,
#  'Oriol Paulo': 2,
#  'Mike Rianda': 1,
#  'Johannes Roberts': 2,
#  'Robert Pulcini': 1,
#  'Pedro Antonio': 1,
#  'John Wells': 2,
#  'Jonathan Liebesman': 1,
#  'Maria Pulera': 1,
#  'Santhosh Viswanath': 1,
#  'Seema Pahwa': 1,
#  'Ozan Açıktan': 7,
#  'Meltem Bozoflu': 2,
#  'Hakan Algül': 8,
#  'Selçuk Aydemir': 2,
#  'Ömer Faruk Sorak': 2,
#  'Şenol Sönmez': 2,
#  'Alexis Morante': 2,
#  'Burak Aksak': 3,
#  'Kıvanç Baruönü': 5,
#  'Rindala Kodeih': 1,
#  'Kongkiat Khomsiri': 1,
#  'Bedran Güzel': 3,
#  'Marwan Nabil': 1,
#  'MIKIKO': 1,
#  'Takashi Shimizu': 1,
#  'Joe Penna': 1,
#  'Ahishor Solomon': 2,
#  'Curtis Graham': 1,
#  'Gerardo Gatica': 1,
#  'Akshay Sanjeev Chavan': 1,
#  'John Madden': 1,
#  'Edward James Olmos': 1,
#  'Abhinay Deo': 3,
#  'Kiran Rao': 1,
#  'Abbas Tyrewala': 1,
#  'Ashutosh Gowariker': 6,
#  'Satyajit Bhatkal': 2,
#  'Anusha Rizvi': 1,
#  'Aamir Khan': 1,
#  'Shashank Khaitan': 2,
#  'Ryan Crego': 1,
#  'Cassi Simonds': 1,
#  'Guillermo del Toro': 3,
#  'Tony Abulu': 1,
#  'Stefan Westerwelle': 1,
#  'Ron Howard': 7,
#  'Justin Benson': 2,
#  'Niki Caro': 1,
#  'Mark Dennis': 1,
#  'Taranveer Singh': 1,
#  'TT The Artist': 1,
#  'Keiichi Sato': 1,
#  'Glenn Weiss': 1,
#  'Michael Civille': 1,
#  'Ryuichi Hiroki': 1,
#  'One9': 1,
#  'Luis Valdez': 2,
#  'Cheng Wei-hao': 1,
#  'Pass Patthanakumjon': 1,
#  'Buchi Babu Sana': 1,
#  'Fredrick Munk': 1,
#  'Moyoung Jin': 1,
#  'Zhao Ji': 1,
#  'Jamie Babbit': 1,
#  'Park Hoon-jung': 2,
#  'Dare Olaitan': 1,
#  'Ben Falcone': 1,
#  'Travon Free': 1,
#  'Angga Dwimas Sasongko': 5,
#  'Steve Rolston': 1,
#  'Shalini Kantayya': 2,
#  'Madonne Ashwin': 1,
#  'Enah Johnscott': 1,
#  'Braden R. Duemmler': 1,
#  'Cal Brunker': 1,
#  'Steve Pink': 1,
#  'Xiao Feng': 1,
#  'Ricky Staub': 1,
#  'Patrick Durham': 1,
#  'BB Sasore': 3,
#  'Naseef Yusuf Izuddin': 1,
#  'Appie Boudellah': 1,
#  'Sylvie Verheyde': 2,
#  'Nick Moore': 1,
#  'Alex Zamm': 2,
#  'Rajkumar Hirani': 3,
#  'Rajesh Mapuskar': 1,
#  'Lina Al Abed': 1,
#  'James Wan': 3,
#  'David Hackl': 1,
#  'Takeshi Nozue': 1,
#  'Subhash Kapoor': 1,
#  'Ringo Lam': 2,
#  'George Cukor': 1,
#  'Tony Giglio': 2,
#  'Shinji Aramaki': 2,
#  'John Luessenhop': 1,
#  'Hanung Bramantyo': 8,
#  'Bashir El Deek': 1,
#  'Roman Polański': 1,
#  'Nelson McCormick': 2,
#  'Mic Rodgers': 1,
#  'Shawn Rech': 1,
#  'Peyton Reed': 3,
#  'Julian Schnabel': 1,
#  'Adrián García Bogliano': 1,
#  'Jose Gomez': 1,
#  'Jonathon Link': 1,
#  'Blair Simmons': 3,
#  'Justin Chadwick': 1,
#  'John Hillcoat': 2,
#  'Nadine Ibrahim': 1,
#  'Roman White': 1,
#  'Fermín Muguruza': 1,
#  'Mike Hodges': 1,
#  'Eylem Kaftan': 1,
#  'Fernando Ayllón': 8,
#  'Umesh Bist': 1,
#  'Massimiliano Camaiti': 1,
#  'Aleksey Tsitsilin': 1,
#  'Ali Tabrizi': 1,
#  'Kagiso Lediga': 2,
#  'Jung-ah Im': 2,
#  'Takuma Sato': 1,
#  'Brody Chu': 1,
#  'Dimitri Logothetis': 2,
#  'Taketoshi Sado': 1,
#  'Li Weiran': 1,
#  'Chinaza Onuzo': 1,
#  'Anna Elizabeth James': 1,
#  'Vitor Brandt': 1,
#  'Troy Miller': 8,
#  "Liam O'Donnell": 2,
#  'Manny Rodriguez': 6,
#  'Farah Nabulsi': 1,
#  'Walter Taylaur': 2,
#  'Chris Smith': 3,
#  'Alain Brunard': 1,
#  'Tate Taylor': 3,
#  'Ladislaus Kiraly': 1,
#  'Oliver Stone': 5,
#  'Hemambar Jasti': 1,
#  'Taylor Morden': 1,
#  'Helena Coan': 1,
#  'Muharrem Gülmez': 2,
#  'Dolapo Adeleke': 1,
#  'Mahsun Kırmızıgül': 2,
#  'Can Ulkay': 1,
#  'Luis Alejandro Pérez': 1,
#  'Ketche': 1,
#  'Erol Özlevi': 1,
#  'Miguel Arteta': 2,
#  'Tolga Örnek': 1,
#  'Pablo Agüero': 1,
#  'Mohammad Irfan Ramly': 1,
#  'Kevin McManus': 1,
#  'Ange Basterga': 1,
#  'Gitanjali Rao': 1,
#  'Halitha Shameem': 2,
#  'Carlos Moreno': 1,
#  'Maribel Sánchez-Maroto': 1,
#  'Fajar Bustomi': 4,
#  'Taylor Hackford': 1,
#  'Amy Poehler': 2,
#  'Jared Hess': 3,
#  'Mike Binder': 2,
#  'Abir Sengupta': 1,
#  'Sunny Lau': 1,
#  'Emmett Malloy': 1,
#  'Xavier Maingon': 1,
#  'Milton Kremer': 1,
#  'Kevin Costner': 1,
#  'Marco Petry': 1,
#  'Andrew Duncan': 1,
#  'Liam Lynch': 2,
#  'Jérémie Degruson': 1,
#  'Matt Ross': 1,
#  'Dani de la Orden': 1,
#  'Pablo Larraín': 3,
#  'John Erick Dowdle': 2,
#  'Jesse Peretz': 1,
#  'Ribhu Dasgupta': 3,
#  'Rizki Balki': 1,
#  'Shunsuke Kariyama': 1,
#  'Jeferson De': 1,
#  'Barry Avrich': 4,
#  'David Tryhorn': 1,
#  'Tirumala Kishore': 1,
#  'Huang Hsin-Yao': 1,
#  'Saron Sakina': 1,
#  'J Blakeson': 1,
#  'Khalid Rahman': 1,
#  'Luis Ara': 4,
#  'Tharun Bhascker Dhaassyam': 1,
#  'Prateek Vats': 1,
#  'Alex Merkin': 2,
#  'Vikram Bhatt': 2,
#  'Dallas Jenkins': 1,
#  'Damián Romay': 2,
#  'Hamisha Daryani Ahuja': 1,
#  'Hong Khaou': 1,
#  'Mario Briongos': 1,
#  'Vinay Bharadwaj': 1,
#  'Michael Fimognari': 2,
#  'Eric D. Cabello Díaz': 1,
#  'Clara Martínez-Lázaro': 1,
#  'Monty Tiwa': 1,
#  'Ava DuVernay': 5,
#  'Alain Darborg': 1,
#  'Filip Zylber': 1,
#  'Julien Royal': 1,
#  'Brian Baugh': 1,
#  'Henri Wong': 1,
#  'Maïa Sandoz': 1,
#  'Mostofa Sarwar Farooki': 1,
#  'Joseph Hsu': 1,
#  'Sam Levinson': 1,
#  'Jo Sung-hee': 1,
#  'Michèle Ohayon': 3,
#  'Rocco Ricciardulli': 1,
#  'Guo Jingming': 1,
#  'Jan Belcl': 1,
#  'Esteban Crespo': 2,
#  'Noé González': 1,
#  'Sarah Gavron': 2,
#  'Martin Scorsese': 12,
#  'Richard Arellano': 1,
#  'Jon Favreau': 2,
#  'Marco Pontecorvo': 1,
#  'Gregory Plotkin': 1,
#  'Lluís Quílez': 1,
#  'Jude Weng': 1,
#  'Simon Stone': 2,
#  'Noviandra Santosa': 1,
#  'Jeremy Grant': 1,
#  'Jeo Baby': 1,
#  'Glendyn Ivin': 1,
#  'Okey Oku': 1,
#  'Ifeanyi Ikpoenyi': 1,
#  'Chris Eneng Enaji': 1,
#  'Ángeles Reiné': 1,
#  'Paul Haggis': 2,
#  'Ramin Bahrani': 1,
#  'Nicol Paone': 1,
#  'Nick Rowland': 1,
#  'RZA': 2,
#  'Cooper Karl': 1,
#  'Gary Fleder': 2,
#  'J.A. Bayona': 2,
#  'Darren Lynn Bousman': 2,
#  'Lydia Dean Pilcher': 1,
#  "Cris D'Amato": 1,
#  'Mikael Håfström': 1,
#  'Byeon Hee-sun': 1,
#  'Peter Facinelli': 1,
#  'Renuka Shahane': 1,
#  'Ross Kauffman': 1,
#  'Sung Do-jun': 1,
#  'Charles Gozali': 1,
#  'James Toback': 2,
#  'Tiller Russell': 3,
#  "Francisco D'Eufemia": 1,
#  'Chris Rock': 1,
#  'Juliet May': 1,
#  'Stanley Nelson': 2,
#  'Olivier Nakache': 1,
#  'Prakash Jha': 5,
#  'Rohan Sippy': 1,
#  'Ross Venokur': 1,
#  'Rohena Gera': 1,
#  'Maite Ruiz De Austri': 1,
#  'Jastis Arimba': 1,
#  'Eric Summer': 1,
#  'Kornél Mundruczó': 1,
#  'Alejandro Ruax': 1,
#  'Florent Bodin': 2,
#  'Sohail Khan': 1,
#  'Hallvard Bræin': 1,
#  'Jeff Tremaine': 2,
#  'Christian Alvart': 1,
#  'Robert Townsend': 1,
#  'Jeff Deverett': 1,
#  'Ron Krauss': 1,
#  'Brian Robbins': 2,
#  'Jeff Stilson': 1,
#  'Sean Penn': 2,
#  'Mark McQueen': 1,
#  'Melanie Mayron': 1,
#  'Donald Petrie': 1,
#  'Tony Collingwood': 1,
#  'Jennifer Beamish': 1,
#  'Jaume Collet-Serra': 1,
#  'Kim Dong-kyu': 1,
#  'Shaz Bennett': 1,
#  'Samar Shaikh': 1,
#  'Archie Hekagery': 1,
#  'Sabrina Rochelle Kalangie': 1,
#  'Cosima Spender': 3,
#  'Liao Shih-han': 1,
#  'Arnon Manor': 1,
#  'Gore Verbinski': 2,
#  'Al Campbell': 1,
#  'Maïwenn': 1,
#  'Richard Weston': 3,
#  'Vikramaditya Motwane': 4,
#  'Prime Cruz': 1,
#  'Andibachtiar Yusuf': 3,
#  'Yandy Laurens': 1,
#  'Cathy Garcia-Molina': 13,
#  'John Mitchell': 1,
#  'George Clooney': 2,
#  'Liu Kuang-hui': 1,
#  'Kristian Mercado': 2,
#  'Daan Jansen': 1,
#  'Jay Grace': 1,
#  'Paul Dugdale': 4,
#  'James Haslam': 1,
#  'Muhammad Ali': 1,
#  'Thomas Toby Parkinson': 1,
#  'John Putch': 1,
#  'Sam Macaroni': 1,
#  'George C. Wolfe': 2,
#  'Yasmin Ahmad': 3,
#  'Sudha Kongara': 1,
#  'Juan Camilo Pinzon': 1,
#  'Lin Oeding': 1,
#  'Naya Anindita': 1,
#  'Alexx Media': 1,
#  'Farishad I. Latjuba': 1,
#  'Andrucha Waddington': 1,
#  'Picky Talarico': 1,
#  'Jun Lana': 4,
#  'Brad Peyton': 2,
#  'Lee Daniels': 1,
#  'Tom Ford': 2,
#  'Ellena Wood': 1,
#  'Vir Das': 2,
#  'Miranda de Pencier': 1,
#  'Farhad Safinia': 1,
#  'Shaun Paul Piccinino': 4,
#  'Eddie Rosas': 1,
#  'Frank E. Abney III': 1,
#  'James D. Stern': 1,
#  'Ryan Murphy': 2,
#  'Girish Malik': 2,
#  'Deepa Mehta': 1,
#  'Lai Chun-yu': 1,
#  'Theodore Boborol': 3,
#  'Sydney Sibilia': 1,
#  'Josiah Ng': 1,
#  'Kirk Wise': 1,
#  'Beth Sleven': 1,
#  'Jalil Lespert': 3,
#  'Su I-Hsuan': 1,
#  'Clint Butler': 1,
#  'Erik Kling': 1,
#  'Detlev Buck': 5,
#  'Amanda Raymond': 1,
#  'Jason Paul Laxamana': 2,
#  'Marc Fouchard': 1,
#  "Darragh O'Connell": 1,
#  'Roberto Santucci': 1,
#  'Dado C. Lumibao': 1,
#  'August Jakobsson': 1,
#  'Anna Wieczur-Bluszcz': 1,
#  'Damien O’Connor': 2,
#  'Richard Laxton': 1,
#  'Gil Kenan': 1,
#  'Phil Burgers': 1,
#  'Pierre Morel': 2,
#  'Brian Henson': 1,
#  'Derick Cabrido': 1,
#  'Marla M. Ancheta': 1,
#  'Jen McGowan': 1,
#  'Bernie Denk': 2,
#  'Brian Skiba': 1,
#  'Stanley Moore': 2,
#  'Oliver Bokelberg': 1,
#  'Ángel Gómez Hernández': 1,
#  'Ludovico Di Martino': 1,
#  'Lee Chung-hyun': 1,
#  'Barry Gonzalez': 1,
#  'Brian Volk-Weiss': 2,
#  'Matthew Michael Carnahan': 1,
#  'Eric Bress': 1,
#  'Chris Columbus': 1,
#  'V Vignarajan': 2,
#  'Greg Rankin': 2,
#  'Carlos Sorín': 1,
#  'Matt Eskandari': 1,
#  'Grant Singer': 1,
#  'Mohammad Adel': 1,
#  'Debbie Allen': 1,
#  'Victor Gatonye': 1,
#  'Stephen Chiodo': 2,
#  'Will McCormack': 1,
#  'Monica Floyd': 1,
#  'Anurag Kashyap': 7,
#  'Siddique': 1,
#  'Danish Aslam': 1,
#  'Vibhu Virender Puri': 1,
#  'Mike Rohl': 1,
#  'Shyam Benegal': 4,
#  'Takeshi Fukunaga': 1,
#  'Leslie Small': 7,
#  'Jeff Nichols': 3,
#  'Sabaah Folayan': 1,
#  'Justin G. Dyck': 7,
#  'Cody Cameron': 1,
#  'Michael Curtiz': 1,
#  'Avinash Walzade': 1,
#  'David E. Talbert': 2,
#  'Renata Terra': 1,
#  'Edoardo Ponti': 1,
#  'Mateo Gil': 2,
#  'Paul Soriano': 2,
#  'Ryan Coogler': 2,
#  'Anurag Basu': 4,
#  'Lucas Santa Ana': 1,
#  'Carla Barros': 1,
#  'Ulrike Kofler': 1,
#  'Steven Bognar': 2,
#  'Kunle Afolayan': 8,
#  'Weica Wang': 1,
#  'Aitor Arregi': 2,
#  'Kevin Pollak': 1,
#  'Otoja Abit': 1,
#  'Alejandro Hartmann': 1,
#  'Maxwell McGuire': 1,
#  'Ruel S. Bayani': 2,
#  'Martin Wood': 1,
#  'Narendra Nath': 1,
#  'Jan-Peter Horns': 1,
#  'Tatsushi Omori': 1,
#  'Estela Renner': 2,
#  ...}

# %% [markdown]
# Ahora a partir de este diccionario creado, voy a crear una nueva columna Recurrent_director donde va a aparecer "Yes" si el director aparece más de 1 vez en la columna First_name_director o "No" si aparece solo 1 vez. Los valores nulos los mantendré como nulos.

# %%
#Genero la nueva columna recurrent_director a partir de first_name_director aplicandole una función lambda (que en primer lugar revisa si el registro es nulo y si lo es, devuelve un nulo, y si no lo es entonces devuelve "Yes" cuando indexando en el diccionario por el nombre del director que es la clave devuelve un valor que es el número de veces que aparece el director > 1, si no devuele "No")
df_netflix_final["Recurrent_director"] = df_netflix_final.apply(lambda x: np.nan if pd.isnull(x["First_name_director"]) else "Yes" if numero_veces_director[x["First_name_director"]] > 1 else "No", axis=1)
df_netflix_final.head()
# Out:
#   Show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water  Sin informacion
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  Sin informacion
# 4      s5  TV Show           Kota Factory  Sin informacion
#
#                                                 Cast        Country  \
# 0                                    Sin informacion  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                    Sin informacion            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   Date_added  Release_year Rating   Duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA        NaN
# 3 2021-09-24          2021  TV-MA        NaN
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                            Listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          Description        Genre    Premiere  \
# 0  As her father nears the end of his life, filmm...  Documentary  2020-10-02
# 1  After crossing paths at a party, a Cape Town t...          NaN         NaN
# 2  To protect his family from a powerful drug lor...          NaN         NaN
# 3  Feuds, flirtations and toilet talk go down amo...          NaN         NaN
# 4  In a city of coaching centers known to train I...          NaN         NaN
#
#    Runtime  IMDB_score Language Month_premiere  Year_premiere Day_premiere  \
# 0     90.0         7.5  English        October         2020.0      Viernes
# 1      NaN         NaN      NaN            NaN            NaN          NaN
# 2      NaN         NaN      NaN            NaN            NaN          NaN
# 3      NaN         NaN      NaN            NaN            NaN          NaN
# 4      NaN         NaN      NaN            NaN            NaN          NaN
#
#   Original_title Duration_cleaned Rating_categorized Has_famous_actor  \
# 0            Yes               90              Teens              NaN
# 1            NaN                2             Adults            False
# 2            NaN              NaN             Adults            False
# 3            NaN              NaN             Adults              NaN
# 4            NaN                2             Adults            False
#
#    Is_recent Decade    First_actor First_name_director         Num_cast  \
# 0       True  2020s            NaN     Kirsten Johnson  Sin informacion
# 1       True  2020s     Ama Qamata                 NaN               19
# 2       True  2020s  Sami Bouajila     Julien Leclercq                9
# 3       True  2020s            NaN                 NaN  Sin informacion
# 4       True  2020s     Mayur More                 NaN                8
#
#   Recurrent_director
# 0                 No
# 1                NaN
# 2                Yes
# 3                NaN
# 4                NaN
